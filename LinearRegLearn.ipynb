# %%
import pandas
import numpy as ny
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[3,5,6,7,8,8]
x_sin =ny.linspace(0,6*ny.pi,200)
y_sin=ny.sin(x_sin)
plt.scatter(x_sin,y_sin)
plt.plot(x_sin,y_sin)
plt.show()
